# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Introduction</div>

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# Spotify is a big music platform. It has songs of various genres. The data I’m going to use in this project only has 15 genres. The goal here is to analyze all the genres with different features and check how they relate to genres.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Data Loading</div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = [15,8]
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("datasets/spotify/genres_v2.csv")
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# 3          0.000000    0.1140   0.1750  ...  0VSXnJqQkwuH2ei1nOQ1nu
# 4          0.000000    0.1660   0.5910  ...  4jCeguq9rMTlbMmPHuO7S3
#
#                                     uri  \
# 0  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# 1  spotify:track:7pgJBLVz5VmnL7uGHmRj6p
# 2  spotify:track:0vSWgAlfpye0WCGeNmuNhy
# 3  spotify:track:0VSXnJqQkwuH2ei1nOQ1nu
# 4  spotify:track:4jCeguq9rMTlbMmPHuO7S3
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
# 1  https://api.spotify.com/v1/tracks/7pgJBLVz5Vmn...
# 2  https://api.spotify.com/v1/tracks/0vSWgAlfpye0...
# 3  https://api.spotify.com/v1/tracks/0VSXnJqQkwuH...
# 4  https://api.spotify.com/v1/tracks/4jCeguq9rMTl...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
# 1  https://api.spotify.com/v1/audio-analysis/7pgJ...      224427
# 2  https://api.spotify.com/v1/audio-analysis/0vSW...       98821
# 3  https://api.spotify.com/v1/audio-analysis/0VSX...      123661
# 4  https://api.spotify.com/v1/audio-analysis/4jCe...      123298
#
#   time_signature      genre                                      song_name  \
# 0              4  Dark Trap                            Mercury: Retrograde
# 1              4  Dark Trap                                      Pathology
# 2              4  Dark Trap                                       Symbiote
# 3              3  Dark Trap  ProductOfDrugs (Prod. The Virus and Antidote)
# 4              4  Dark Trap                                          Venom
#
#   Unnamed: 0 title
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (42305, 22)

# %%
df.isna().sum()
# Out:
# danceability            0
# energy                  0
# key                     0
# loudness                0
# mode                    0
# speechiness             0
# acousticness            0
# instrumentalness        0
# liveness                0
# valence                 0
# tempo                   0
# type                    0
# id                      0
# uri                     0
# track_href              0
# analysis_url            0
# duration_ms             0
# time_signature          0
# genre                   0
# song_name           20786
# Unnamed: 0          21525
# title               21525
# dtype: int64

# %%
df = df.drop(['type', 'uri', 'track_href', 'analysis_url', 'Unnamed: 0', 'title'], 1)

# %%
df.select_dtypes('number').describe().T
# Out:
#                     count           mean            std           min  \
# danceability      42305.0       0.639364       0.156617      0.065100
# energy            42305.0       0.762516       0.183823      0.000243
# key               42305.0       5.370240       3.666145      0.000000
# loudness          42305.0      -6.465442       2.941165    -33.357000
# mode              42305.0       0.549462       0.497553      0.000000
# speechiness       42305.0       0.136561       0.126168      0.022700
# acousticness      42305.0       0.096160       0.170827      0.000001
# instrumentalness  42305.0       0.283048       0.370791      0.000000
# liveness          42305.0       0.214079       0.175576      0.010700
# valence           42305.0       0.357101       0.233200      0.018700
# tempo             42305.0     147.474056      23.844623     57.967000
# duration_ms       42305.0  250865.846685  102957.713571  25600.000000
# time_signature    42305.0       3.972580       0.268342      1.000000
#
#                            25%           50%         75%         max
# danceability           0.52400       0.64600       0.766       0.988
# energy                 0.63200       0.80300       0.923       1.000
# key                    1.00000       6.00000       9.000      11.000
# loudness              -8.16100      -6.23400      -4.513       3.148
# mode                   0.00000       1.00000       1.000       1.000
# speechiness            0.04910       0.07550       0.193       0.946
# acousticness           0.00173       0.01640       0.107       0.988
# instrumentalness       0.00000       0.00594       0.722       0.989
# liveness               0.09960       0.13500       0.294       0.988
# valence                0.16100       0.32200       0.522       0.988
# tempo                129.93100     144.97300     161.464     220.290
# duration_ms       179840.00000  224760.00000  301133.000  913052.000
# time_signature         4.00000       4.00000       4.000       5.000

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Data Distribution</div>

# %%
categorical_cols = ['time_signature', 'genre']

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15,6))
axs = np.ravel(axs)

for i, col in enumerate(categorical_cols):
    plt.sca(axs[i])
    sns.countplot(data=df, x=col)
    plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - Data contains only a few instances of ‘time signature’ 1, 3, and 5. Most instances are 4 ‘time signature’.
# - Underground Rap has the maximum number, and Pop has the minimum number of instances.
# </div>

# %%
numerical_cols = df.select_dtypes('number').drop('time_signature', 1).columns.to_list()

# %%
fig, axs = plt.subplots(nrows=4, ncols=3, figsize=(15,20))
axs = np.ravel(axs)

for i, col in enumerate(numerical_cols):
    plt.sca(axs[i])
    sns.histplot(data=df, x=col, kde=True, fill=True, color='orange')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - Danceability follows an approximately normal distribution.
# - Energy feature if negatively skewed.
# - The loudness feature is normally distributed with a few outliers.
# - The number of instances with mode 1 is greater than mode 0.
# - The Speechiness feature is positively skewed, meaning the 'speechiness' feature's mean is greater than the median.
# - 'Acousticness', 'instrumentalness', 'liveness', and valence features are all p[olsitively skewed.
# - The "temp" and "duration_ms" features seem to have a normal distribution.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Song Genre and Danceability</div>

# %%
def plot_genre_horizontal_bar(col, title=None):
    data = df.groupby('genre')[col].mean().sort_values()

    cmap = plt.cm.coolwarm_r
    norm = plt.Normalize(vmin=data.min(), vmax=data.max())
    colors = [cmap(norm(value)) for value in data]

    data.plot.barh(color=colors)
    plt.xlabel(col)
    plt.title(title, fontdict={'size': 18, 'color': '#de5d83'})
    plt.show()

# %%
sns.boxplot(data=df, x='genre', y='danceability')
plt.xticks(rotation=15)
plt.show()

# %%
plot_genre_horizontal_bar('danceability',
                          title="Average Danceability in each genre")

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - Songs in the genre 'techhouse' have the maximum average danceability, followed by underground Rap. And hardstyle songs have minimum danceability.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Song Genre and Energy</div>

# %%
sns.boxplot(data=df, x='genre', y='energy')
plt.xticks(rotation=15)
plt.show()

# %%
plot_genre_horizontal_bar('energy', title="Average energy in each genre")

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - Songs in genre "trap", "psytrance", "hardstyle", "trance", or "dnb" have the highest energy, and RnB, Rap, or Underground Rap lowest.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Song Genre and Loudness</div>

# %%
sns.boxplot(data=df, x='genre', y='loudness')
plt.xticks(rotation=15)
plt.show()

# %%
plot_genre_horizontal_bar('loudness', title="Average loudness in each genre")

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - Songs in all genres have loudness scores in negatives. "Trap" genre has the highest "loudness", and "techno" genre lowest.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Song Genre and Speechiness</div>

# %%
sns.boxplot(data=df, x='genre', y='speechiness')
plt.xticks(rotation=15)
plt.show()

# %%
plot_genre_horizontal_bar('speechiness',
                          title='Average speechiness in each genre')

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - Underground Rap, Rap, and Hiphop are the top-3 genres for “speechiness”, and trance, techno, and psytrance are the lowest.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Song Genre and Acousticness</div>

# %%
sns.boxplot(data=df, x='genre', y='acousticness')
plt.xticks(rotation=15)
plt.show()

# %%
plot_genre_horizontal_bar('acousticness',
                          title='Average acousticness in each genre')

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - Songs in genre 'RnB' have the minimum acousticness score and followed by Hiphop and Rap.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Song Genre and Instrumentalness</div>

# %%
sns.boxplot(data=df, x='genre', y='instrumentalness')
plt.xticks(rotation=15)
plt.show()

# %%
plot_genre_horizontal_bar('instrumentalness',
                          title='Average instrumentalness in each genre')

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - The 'techno' genre songs have the maximum instrumentalness score, followed by 'psytrance' genre.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Song Genre and Liveness</div>

# %%
sns.boxplot(data=df, x='genre', y='liveness')
plt.xticks(rotation=15)
plt.show()

# %%
plot_genre_horizontal_bar('liveness', title='Average liveness in each genre')

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - "Trance" and "psytrance" are the top genres with liveness scores.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Song Genre and Valence</div>

# %%
sns.boxplot(data=df, x='genre', y='valence')
plt.xticks(rotation=15)
plt.show()

# %%
plot_genre_horizontal_bar('valence', title='Average valance in each genre')

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - The valence bis maximum for 'techhouse' genre followed by Pop and minimum for 'techno' and 'trance'.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Song Genre and Tempo</div>

# %%
sns.boxplot(data=df, x='genre', y='tempo')
plt.xticks(rotation=15)
plt.show()

# %%
plot_genre_horizontal_bar('tempo', title='Average tempo in each genre')

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - Tempo score the highest for 'dnb' genre followed by 'Hiphop' genre. And 'techhouse' has the lowest.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Song Genre and Time Duration</div>

# %%
sns.boxplot(data=df, x='genre', y='duration_ms')
plt.xticks(rotation=15)
plt.show()

# %%
plot_genre_horizontal_bar('duration_ms',
                          title='Average time duration in each genre')

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - Songs in genres 'psytrance' and 'techno' are the longest than all other genres.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Song Genre and Mode</div>

# %%
data = (df
        .groupby(['genre', 'mode'])['mode']
        .count()
        .unstack(1))

data.style.background_gradient(cmap=plt.cm.coolwarm_r)
# Out:
# <style type="text/css">
# #T_16078_row0_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_16078_row0_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_16078_row1_col0 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_16078_row1_col1 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_16078_row2_col0 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_16078_row2_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_16078_row3_col0, #T_16078_row3_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_16078_row4_col0 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_16078_row4_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_16078_row5_col0 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_16078_row5_col1 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_16078_row6_col0 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_16078_row6_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_16078_row7_col0, #T_16078_row7_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_16078_row8_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_16078_row8_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_16078_row9_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_16078_row9_col1 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_16078_row10_col0, #T_16078_row14_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_16078_row10_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_16078_row11_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_16078_row11_col1 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_16078_row12_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_16078_row12_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_16078_row13_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_16078_row13_col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_16078_row14_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# </style>
# <table id="T_16078_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mode</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >genre</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16078_level0_row0" class="row_heading level0 row0" >Dark Trap</th>
#       <td id="T_16078_row0_col0" class="data row0 col0" >2122</td>
#       <td id="T_16078_row0_col1" class="data row0 col1" >2456</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row1" class="row_heading level0 row1" >Emo</th>
#       <td id="T_16078_row1_col0" class="data row1 col0" >528</td>
#       <td id="T_16078_row1_col1" class="data row1 col1" >1152</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row2" class="row_heading level0 row2" >Hiphop</th>
#       <td id="T_16078_row2_col0" class="data row2 col0" >1430</td>
#       <td id="T_16078_row2_col1" class="data row2 col1" >1598</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row3" class="row_heading level0 row3" >Pop</th>
#       <td id="T_16078_row3_col0" class="data row3 col0" >208</td>
#       <td id="T_16078_row3_col1" class="data row3 col1" >253</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row4" class="row_heading level0 row4" >Rap</th>
#       <td id="T_16078_row4_col0" class="data row4 col0" >883</td>
#       <td id="T_16078_row4_col1" class="data row4 col1" >965</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row5" class="row_heading level0 row5" >RnB</th>
#       <td id="T_16078_row5_col0" class="data row5 col0" >982</td>
#       <td id="T_16078_row5_col1" class="data row5 col1" >1117</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row6" class="row_heading level0 row6" >Trap Metal</th>
#       <td id="T_16078_row6_col0" class="data row6 col0" >552</td>
#       <td id="T_16078_row6_col1" class="data row6 col1" >1404</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row7" class="row_heading level0 row7" >Underground Rap</th>
#       <td id="T_16078_row7_col0" class="data row7 col0" >2270</td>
#       <td id="T_16078_row7_col1" class="data row7 col1" >3605</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row8" class="row_heading level0 row8" >dnb</th>
#       <td id="T_16078_row8_col0" class="data row8 col0" >1643</td>
#       <td id="T_16078_row8_col1" class="data row8 col1" >1323</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row9" class="row_heading level0 row9" >hardstyle</th>
#       <td id="T_16078_row9_col0" class="data row9 col0" >1877</td>
#       <td id="T_16078_row9_col1" class="data row9 col1" >1059</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row10" class="row_heading level0 row10" >psytrance</th>
#       <td id="T_16078_row10_col0" class="data row10 col0" >1189</td>
#       <td id="T_16078_row10_col1" class="data row10 col1" >1772</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row11" class="row_heading level0 row11" >techhouse</th>
#       <td id="T_16078_row11_col0" class="data row11 col0" >1287</td>
#       <td id="T_16078_row11_col1" class="data row11 col1" >1688</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row12" class="row_heading level0 row12" >techno</th>
#       <td id="T_16078_row12_col0" class="data row12 col0" >1234</td>
#       <td id="T_16078_row12_col1" class="data row12 col1" >1722</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row13" class="row_heading level0 row13" >trance</th>
#       <td id="T_16078_row13_col0" class="data row13 col0" >1671</td>
#       <td id="T_16078_row13_col1" class="data row13 col1" >1328</td>
#     </tr>
#     <tr>
#       <th id="T_16078_level0_row14" class="row_heading level0 row14" >trap</th>
#       <td id="T_16078_row14_col0" class="data row14 col0" >1184</td>
#       <td id="T_16078_row14_col1" class="data row14 col1" >1803</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - In both modes, Underground Rap has the maximum number of instances.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Song Genre and Time Signature</div>

# %%
data = (df
        .groupby(['genre', 'time_signature'])['time_signature']
        .count()
        .unstack(1))

data.style.background_gradient(cmap=plt.cm.coolwarm_r)
# Out:
# <style type="text/css">
# #T_bb757_row0_col0, #T_bb757_row0_col1, #T_bb757_row0_col3, #T_bb757_row7_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_bb757_row0_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_bb757_row1_col0, #T_bb757_row6_col0, #T_bb757_row14_col0 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_bb757_row1_col1, #T_bb757_row9_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_bb757_row1_col2 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_bb757_row1_col3 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_bb757_row2_col0, #T_bb757_row7_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_bb757_row2_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_bb757_row2_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_bb757_row2_col3 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_bb757_row3_col0, #T_bb757_row11_col0 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_bb757_row3_col1, #T_bb757_row10_col3, #T_bb757_row11_col3 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_bb757_row3_col2, #T_bb757_row8_col0, #T_bb757_row8_col1, #T_bb757_row8_col3, #T_bb757_row13_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bb757_row3_col3 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_bb757_row4_col0, #T_bb757_row9_col0 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_bb757_row4_col1 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_bb757_row4_col2 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_bb757_row4_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_bb757_row5_col0 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_bb757_row5_col1, #T_bb757_row8_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_bb757_row5_col2 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_bb757_row5_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_bb757_row6_col1 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_bb757_row6_col2 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_bb757_row6_col3 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_bb757_row7_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_bb757_row7_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_bb757_row9_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_bb757_row9_col3 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_bb757_row10_col0, #T_bb757_row13_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_bb757_row10_col1 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_bb757_row10_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_bb757_row11_col1, #T_bb757_row14_col3 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_bb757_row11_col2, #T_bb757_row13_col2, #T_bb757_row14_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_bb757_row12_col0 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_bb757_row12_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_bb757_row12_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_bb757_row12_col3 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_bb757_row13_col1 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_bb757_row14_col1 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bb757_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >time_signature</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >3</th>
#       <th class="col_heading level0 col2" >4</th>
#       <th class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >genre</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb757_level0_row0" class="row_heading level0 row0" >Dark Trap</th>
#       <td id="T_bb757_row0_col0" class="data row0 col0" >37.000000</td>
#       <td id="T_bb757_row0_col1" class="data row0 col1" >181.000000</td>
#       <td id="T_bb757_row0_col2" class="data row0 col2" >4245.000000</td>
#       <td id="T_bb757_row0_col3" class="data row0 col3" >115.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb757_level0_row1" class="row_heading level0 row1" >Emo</th>
#       <td id="T_bb757_row1_col0" class="data row1 col0" >8.000000</td>
#       <td id="T_bb757_row1_col1" class="data row1 col1" >92.000000</td>
#       <td id="T_bb757_row1_col2" class="data row1 col2" >1567.000000</td>
#       <td id="T_bb757_row1_col3" class="data row1 col3" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb757_level0_row2" class="row_heading level0 row2" >Hiphop</th>
#       <td id="T_bb757_row2_col0" class="data row2 col0" >23.000000</td>
#       <td id="T_bb757_row2_col1" class="data row2 col1" >64.000000</td>
#       <td id="T_bb757_row2_col2" class="data row2 col2" >2882.000000</td>
#       <td id="T_bb757_row2_col3" class="data row2 col3" >59.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb757_level0_row3" class="row_heading level0 row3" >Pop</th>
#       <td id="T_bb757_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_bb757_row3_col1" class="data row3 col1" >6.000000</td>
#       <td id="T_bb757_row3_col2" class="data row3 col2" >448.000000</td>
#       <td id="T_bb757_row3_col3" class="data row3 col3" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb757_level0_row4" class="row_heading level0 row4" >Rap</th>
#       <td id="T_bb757_row4_col0" class="data row4 col0" >7.000000</td>
#       <td id="T_bb757_row4_col1" class="data row4 col1" >46.000000</td>
#       <td id="T_bb757_row4_col2" class="data row4 col2" >1754.000000</td>
#       <td id="T_bb757_row4_col3" class="data row4 col3" >41.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb757_level0_row5" class="row_heading level0 row5" >RnB</th>
#       <td id="T_bb757_row5_col0" class="data row5 col0" >15.000000</td>
#       <td id="T_bb757_row5_col1" class="data row5 col1" >90.000000</td>
#       <td id="T_bb757_row5_col2" class="data row5 col2" >1941.000000</td>
#       <td id="T_bb757_row5_col3" class="data row5 col3" >53.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb757_level0_row6" class="row_heading level0 row6" >Trap Metal</th>
#       <td id="T_bb757_row6_col0" class="data row6 col0" >8.000000</td>
#       <td id="T_bb757_row6_col1" class="data row6 col1" >115.000000</td>
#       <td id="T_bb757_row6_col2" class="data row6 col2" >1785.000000</td>
#       <td id="T_bb757_row6_col3" class="data row6 col3" >48.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb757_level0_row7" class="row_heading level0 row7" >Underground Rap</th>
#       <td id="T_bb757_row7_col0" class="data row7 col0" >23.000000</td>
#       <td id="T_bb757_row7_col1" class="data row7 col1" >159.000000</td>
#       <td id="T_bb757_row7_col2" class="data row7 col2" >5583.000000</td>
#       <td id="T_bb757_row7_col3" class="data row7 col3" >110.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb757_level0_row8" class="row_heading level0 row8" >dnb</th>
#       <td id="T_bb757_row8_col0" class="data row8 col0" >1.000000</td>
#       <td id="T_bb757_row8_col1" class="data row8 col1" >3.000000</td>
#       <td id="T_bb757_row8_col2" class="data row8 col2" >2961.000000</td>
#       <td id="T_bb757_row8_col3" class="data row8 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb757_level0_row9" class="row_heading level0 row9" >hardstyle</th>
#       <td id="T_bb757_row9_col0" class="data row9 col0" >7.000000</td>
#       <td id="T_bb757_row9_col1" class="data row9 col1" >92.000000</td>
#       <td id="T_bb757_row9_col2" class="data row9 col2" >2829.000000</td>
#       <td id="T_bb757_row9_col3" class="data row9 col3" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bb757_level0_row10" class="row_heading level0 row10" >psytrance</th>
#       <td id="T_bb757_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_bb757_row10_col1" class="data row10 col1" >117.000000</td>
#       <td id="T_bb757_row10_col2" class="data row10 col2" >

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - Except for 'time-signature' 4, all have the maximum number of instances in the 'Dark Trap' genre. Underground Rap has the maximum number of instances in the 'time-signature' 4.
# </div>

# %% [markdown]
# ## <div style="background:#96DDD5; padding:1rem">Correlation</div>

# %%
corr_mat = df[numerical_cols].corr()

sns.heatmap(corr_mat,
            annot=True,
            fmt='.2f',
            cmap=plt.cm.coolwarm_r,
            mask=np.triu(corr_mat, k=0))
plt.show()

# %% [markdown]
# <div style="background:#fae7b5; padding:1.5rem; font-size:1.5rem">
#
# - 'Danceability' has positive correlation with 'valence' feature.
# - 'Energy' has positive correlation with 'loudness', 'instrumentalness', 'liveness', and 'time duration'.
# - 'Instrumentalness' has positive correlation with 'time duration'.
#
# </div>
